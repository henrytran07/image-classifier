# %%
import sys
sys.path.append('..')

from utils.data_utils import load_mnist_ds, load_dense_model_ds, load_cnn_model_ds
from utils.activations import z_score_normalization, relu, softmax, cce_loss
from utils.layers import init_linear_params, forward_prop 
import numpy as np 
import matplotlib.pyplot as plt

# %%
x_train_dm, y_train, x_test_dm, y_test = load_dense_model_ds() 
x_train_cnn, y_train, x_test_cnn, y_test = load_cnn_model_ds() 
print(x_train_dm.shape)
# Out:
# (784, 60000)

# %%
x_train_dm_normalized = z_score_normalization(x_train_dm)
print(x_train_dm_normalized.shape)
# Out:
# (784, 60000)

# %%
linear_params = init_linear_params() 
cache, A4 = forward_prop(linear_params, x_train_dm) 
print(A4)
# Out:
# [[9.36307086e-122 1.75597672e-146 3.53360390e-227 ... 1.07573712e-116
#   2.40369766e-110 7.65504950e-078]
#  [1.00000000e+000 1.75713684e-007 2.77381863e-064 ... 9.99028767e-083
#   8.34546709e-041 6.57893720e-023]
#  [9.64448180e-033 9.99999824e-001 1.00000000e+000 ... 4.59102219e-031
#   5.22293810e-001 1.02036750e-008]
#  ...
#  [6.87182420e-165 2.20054558e-167 7.66804697e-235 ... 5.44733970e-130
#   4.95516794e-093 2.16497726e-039]
#  [5.83376331e-151 2.27784847e-137 5.15631090e-165 ... 6.29175659e-077
#   5.51448251e-057 8.60565404e-048]
#  [7.34327636e-030 3.08346688e-109 7.93859958e-183 ... 1.37782317e-101
#   7.60365494e-084 3.05362983e-046]]

# %%
import numpy as np 
z = np.random.randn(50, 100)
A = np.random.rand(*z.shape) < 0.8
z = z * A / 0.8
print(z)
# Out:
# [[ 0.          1.94952225  1.54977641 ... -0.90555143 -2.84129127
#   -0.        ]
#  [-0.         -0.         -2.5552416  ...  0.41502328  0.31064582
#   -0.42060729]
#  [ 1.94089579  1.88384415  2.43066789 ...  1.4477668   0.
#    0.        ]
#  ...
#  [ 2.9796305  -1.30888818  0.         ...  1.70553071 -0.
#   -0.88814244]
#  [ 0.1578492   0.          0.69566686 ... -1.86132358  0.02925398
#   -0.04385302]
#  [ 0.28820315  0.54667425 -0.87950738 ... -1.12438197  0.
#    0.        ]]

# %%
x = np.arange(0, x_train_dm.shape[1]) 
x = np.random.permutation(x) 
x_train_dm = x_train_dm[:, x]
print(x_train_dm)
# Out:
# [[-0.81025766  0.18950704  0.47832795 ... -0.81025766  2.02240898
#    1.01153579]
#  [-0.81025766  2.02240898 -0.05487989 ...  0.22283253  0.47832795
#   -0.78804066]
#  [-0.81025766  0.62273841 -0.81025766 ... -0.81025766 -0.81025766
#    1.76691356]
#  ...
#  [ 1.35589918  1.58917761 -0.81025766 ... -0.81025766  2.02240898
#   -0.81025766]
#  [ 0.90045082 -0.3325923   0.71160638 ... -0.81025766 -0.81025766
#   -0.81025766]
#  [ 0.91155932 -0.81025766  1.35589918 ... -0.81025766  1.57806912
#   -0.81025766]]
